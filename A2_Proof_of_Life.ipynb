# %% [markdown]
# <a href="https://colab.research.google.com/github/lamaramolb-cyber/cml3112-25-ug-1008-bsce-j/blob/main/A2_Proof_of_Life.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello from CML3112")
print(2+2)
# Out:
# Hello from CML3112
# 4

# %%
readings=12
print(f"I have {readings} readings")
# Out:
# I have 12 readings

# %%
readings=readings+5
print(f"readings is now {readings}")
# Out:
# readings is now 17
